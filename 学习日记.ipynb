# %% [markdown]
# # 170810  w0d4
#
# 共投入2.5个小时学习编程（12：00~2：30）
#
# ## 主要学习点如下：
#
# 1. 阅读w0的卡片内容   0.5h
# 2. 摸索安装jupyter notebook，期间阅读相关文档  1h
# 3. 练习使用命令启动jupyter note，出现问题，寻找问题解决方法  0.5h
# 4. 熟悉和练习使用jupyter notebook时发现python3与python2在格式化字符上的不同，查询了解python3的相关更新  0.5h
#
# ## 复盘
#
# 1. 准备好python的开发环境和基本工具
# 2. 基本能使用jupyter notebook
# 3. 在阅读卡片时，过于关于推荐的业余延伸学习的点，导致没有集中来写代码
# 4. 很大比例的时间花在了对工具的深入了解上。
#
# **反思：要明白主次任务，目前下班后回家学习，时间较为紧张，需要先完成编程任务。至于工具，基本能用就ok，再抽周末的时间加深了解和学习。大妈卡片中推荐的延伸阅读也是需要放在上下班时间和周末时间好好学习。**
#
# **编程重在输出。**

# %% [markdown]
# # 170811 w0d5
# 共投入3h学习编程（11：30~2：30） 教材*LPHW*
#
# ## 主要学习点：
#
# 1. ex24 .5h
# 2. ex25  2h
# 3. ex26 .5h
# 4. 回答了一个[issue](https://github.com/AIHackers/Py101-004/issues)，因为自己也遇到了，静下来捋了一遍逻辑，想明白了，改后就正确了。可以来帮其他同学了，体会到了issue的好处
#
# ## 复盘
# 1. 今天的三个小练习是完完全全搞懂，加深了对函数的理解
# 2. 在做ex25的练习中能够举一反三，触类旁通。完全掌握了```pop（）``` 这个BIF。
# >开始不能完全理解pop()这个函数的内参数的含义。查阅官方文档后知道大概意思。然后修改教材中的代码，输入各种不同的参数，看运行结果，最后弄懂。开始体会到“编程的重点”在于输出这句话的意义了。也开始体会到大妈在开学典礼上说的，学编程跟学其他东西没有本质区别，范式都是一样的。熟能生巧，生的是不是自己的“巧”。
# 3. 由于在ex25的练习中自己通过不停的改教材中的代码，已经知道了各种报错的原因。所以修改ex26的代码，两次搞定。改完第一次后，出现一次报错，根据报错定位，迅速发现问题所在，第二次改后，代码就运行正常。

# %% [markdown]
# # 170812~13 w0d6~7
# 共投入12.5个小时学习编程，周六周天熬夜学习（后续调整好时间）
#
# # 主要学习点：
# 1. ex27~ex40
# 2. 课后附加题
#
# # 复盘
#
# *进步：
# 1. 通过练习，加深了对条件语句、循环语句、函数和列表的理解和编程的熟练度
# 2. 学习list的文档，较为全面的掌握其创建、操作（方法）等；学习range的文档，较为完整的掌握range的用法
# 3. 阅读代码、理解代码的能力有所提高，速度可以快起来了
# 4. git命令上传文件；命令行开启jupyter notebook的操作熟练起来了
#
# *不足：
# 1. 0w的学习时间安排不合理，导致学习任务严重挤压到后几天，熬夜完成，得不偿失。而且只能抓住主干，后续还需要抽时间补充一些额外知识。
# 2. 0w 老师的推荐阅读需要补起来
# 3. 0w 学习过程中记录的需要扩展延伸学习的内容：
#     * list 的官方文档
#     * ex33附加题中关于函数的参数引入问题思考
#     * 字典的再学习
#     * ex37、38的复盘学习
